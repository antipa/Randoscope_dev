# %%
import tensorflow as tf
import tensorflow.contrib.eager as tfe
tf.enable_eager_execution()


# %load_ext autoreload   
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
from miniscope_utils_tf import *
from miniscope_model import Model as msu_model
import scipy.misc as sc
from skimage.transform import resize as imresize
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
from IPython import display
import scipy.ndimage as ndim
import scipy.misc as misc
from scipy import signal

import matplotlib.animation as animation
import os
# %matplotlib inline
# Out:
# <style>.container { width:95% !important; }</style>

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
os.listdir("../")
# Out:
# ['garbage',
#  '.bashrc-anaconda3.bak',
#  'checkpoint',
#  'test1_init.data-00000-of-00001',
#  'developer',
#  'data',
#  'learning_lenslets',
#  '.bash_logout',
#  'test1_init.index',
#  'LearnedFISTA.ipynb',
#  'learned_psf_FISTA.mat',
#  '.ipynb_checkpoints',
#  'test.data-00000-of-00001',
#  '.ipython',
#  '__pycache__',
#  'PSFOpt',
#  '.nano',
#  'miniscope_utils_tf.py',
#  '.profile',
#  '.viminfo',
#  'README.md',
#  '.sudo_as_admin_successful',
#  'anaconda3',
#  'high-speed-video-recon',
#  '.gitconfig',
#  '.conda',
#  'environment.yml',
#  'test.index',
#  '.git',
#  '.jupyter',
#  '.bashrc',
#  '.config',
#  '.keras',
#  'miniscope_utils_tf.bak',
#  '.cache',
#  'Miniscope3D',
#  '.bash_history',
#  'test_kyrollos.ipynb',
#  'logsumexp_500.hd5.data-00000-of-00001',
#  '.Xauthority',
#  '.nv',
#  '.local',
#  '.python_history']

# %%
model_init = msu_model()
model_init.load_weights('../test1_init')
surf_init,_ = make_lenslet_tf(model_init)

print(tf.shape(model_init.variables[0]))
print(model_init.Nlenslets)
model_opt1 = msu_model()
model_opt1.load_weights('../test')

f, ax = plt.subplots(3,2,figsize=(20,20))
ax[0,0].imshow(surf_init.numpy())
ax[0,1].plot(Rmat_init.numpy())
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-10-bd8bd2f473de> in <module>()
# ----> 1 model_init = msu_model()
#       2 Rmat_init=model_init(0)
#       3 surf_init,_ = make_lenslet_tf(model_init)
#       4
#       5 print(tf.shape(model_init.variables[0]))
#
# ~/Miniscope3D/miniscope_model.py in __init__(self, zsampling, cross_corr_norm)
#      73         fx = tf.constant(np.linspace(-1./(2.*self.ps),1./(2.*self.ps),self.samples[1]),dtype=tf.float32)
#      74         fy = tf.constant(np.linspace(-1./(2.*self.ps),1./(2.*self.ps),self.samples[0]),dtype=tf.float32)
# ---> 75         self.Fx,self.Fy = tf.meshgrid(fx,fy)
#      76         self.field_list = tf.constant(np.array((0., 0.)).astype('float32'))
#      77
#
# ~/anaconda3/envs/eager-latest/lib/python3.5/site-packages/tensorflow/python/ops/array_ops.py in meshgrid(*args, **kwargs)
#    1994     # TODO(nolivia): improve performance with a broadcast
#    1995     mult_fact = ones(shapes, output_dtype)
# -> 1996     return [x * mult_fact for x in output]
#    1997
#    1998
#
# ~/anaconda3/envs/eager-latest/lib/python3.5/site-packages/tensorflow/python/ops/array_ops.py in <listcomp>(.0)
#    1994     # TODO(nolivia): improve performance with a broadcast
#    1995     mult_fact = ones(shapes, output_dtype)
# -> 1996     return [x * mult_fact for x in output]
#    1997
#    1998
#
# ~/anaconda3/envs/eager-latest/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#     864     with ops.name_scope(None, op_name, [x, y]) as name:
#     865       if isinstance(x, ops.Tensor) and isinstance(y, ops.Tensor):
# --> 866         return func(x, y, name=name)
#     867       elif not isinstance(y, sparse_tensor.SparseTensor):
#     868         try:
#
# ~/anaconda3/envs/eager-latest/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py in _mul_dispatch(x, y, name)
#    1129   is_tensor_y = isinstance(y, ops.Tensor)
#    1130   if is_tensor_y:
# -> 1131     return gen_math_ops.mul(x, y, name=name)
#    1132   else:
#    1133     assert isinstance(y, sparse_tensor.SparseTensor)  # Case: Dense * Sparse.
#
# ~/anaconda3/envs/eager-latest/lib/python3.5/site-packages/tensorflow/python/ops/gen_math_ops.py in mul(x, y, name)
#    5063       else:
#    5064         message = e.message
# -> 5065       _six.raise_from(_core._status_to_exception(e.code, message), None)
#    5066
#    5067
#
# ~/anaconda3/envs/eager-latest/lib/python3.5/site-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[768,768] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Mul] name: meshgrid/mul/

# %%
model_init.load_weights('../test')
