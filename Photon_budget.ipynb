# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#fig = plt.figure()
fwhm = 20 # nm
sig = fwhm/2/np.sqrt(2*np.log(2))


ctlamb = 460
d = {}
with open("/Users/nick.antipa/Downloads/4796-ascii.txt") as f:
    for line in f:
        (key, val) = line.split()
        key_int = int(float(key))
        d[key_int] = val
        
lamb = np.linspace(next(iter(d.keys())),1200,len(d)).astype('int')
# [mydict[x] for x in mykeys]
em_spect = [float(d[x]) for x in lamb]
#print(spect_test)
#em_spect = np.array(list(d.values())).astype('float')


plt.figure()
plt.clf()
plt.plot(lamb,spect_test)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
d_exc = {}

with open("/Users/nick.antipa/Downloads/1970-ascii.txt") as f:
    for line in f:
        (key, val) = line.split()
        key_int = int(float(key))
        d_exc[key_int] = val

lamb2 = np.linspace(next(iter(d_exc.keys())),1200,len(d_exc))
em_spect_smaller = [float(d[x]) for x in lamb3]
#exc_spect_smaller = np.array(list(d_exc.values())).astype('float')
exc_spect_smaller = [float(d_exc[x]) for x in lamb3]
plt.figure()

plt.plot(lamb2,exc_spect)
plt.plot(lamb2,em_spect_smaller)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
d_dich = {}

with open("/Users/nick.antipa/Downloads/5040-ascii.txt") as f:
    for line in f:
        (key, val) = line.split()
        key_int = int(float(key))
        d_dich[key_int] = val
print(next(iter(d_dich.keys())))

lamb3 = np.linspace(next(iter(d_dich.keys())),1000,len(d_dich))
dich_spect = np.array([float(d_dich[x]) for x in lamb3])
#print(dich_spect)
em_spect_smaller = np.array([float(d[x]) for x in lamb3])
#exc_spect_smaller = np.array(list(d_exc.values())).astype('float')
exc_spect_smaller = np.array([float(d_exc[x]) for x in lamb3])
print(em_spect_smaller)
plt.figure()
plt.plot(lamb3,exc_spect_smaller)
plt.plot(lamb3,em_spect_smaller)
plt.plot(lamb3,dich_spect)
#dich_spect = [float(d_dich[x]) for x in lamb2]
# Out:
# 380
# [9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
#  9.50000015e-07 9.50000015e-07 9.50000015e-07 9.50000015e-07
# ...

# %%
plt.figure()
print(type(em_spect_smaller))
T_total_im = exc_spect_smaller*em_spect_smaller*dich_spect*(1-dich_spect)*.96**4
led_spect = np.exp(-(lamb3-ctlamb)**2/2/sig**2)/sig/np.sqrt(2*np.pi)
eta = np.sum(120*led_spect)
F = 35
P = F/eta  # Radiant power, in watts
led_P = led_spect*P
led_pps = led_P/(6.626e-34*3e8/(ctlamb*1e-9))
t_int = 1/30
br = .005
pix_rel_area = 1/(752*480)
QE = .43
gain = 64
plt.plot(lamb3,T_total_im*led_pps*t_int*br*pix_rel_area)
phot_tot = np.sum(T_total_im*led_pps*t_int*br*pix_rel_area)
plt.title('total photons/pixel of background: ' + '%.5f' % phot_tot)
plt.figure()
phot_e_tot = np.sum(T_total_im*led_pps*t_int*br*pix_rel_area*QE*gain)
plt.plot(lamb3,T_total_im*led_pps*t_int*br*pix_rel_area*QE*gain)
plt.title('total counts/pixel of background: ' + '%.5f' % phot_e_tot)
#plt.plot(lamb2,led_spect)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <class 'numpy.ndarray'>
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'total counts/pixel of background: 26.10136')

# %%
# Photon budget for fluorescence

# %%
print(95/2+145/2)
# Out:
# 120.0
